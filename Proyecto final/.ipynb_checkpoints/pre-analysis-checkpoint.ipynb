# %%
import pandas as pd

# %%
#CAMBIAR AQUÍ EL ARCHIVO
jb = pd.read_csv("jb_part.csv")
dt = pd.read_csv("dt_part.csv")

# %%
df = pd.append()
# Out:
# (97092, 22)

# %% [markdown]
# # CARACTERISTICAS DE LA BASE

# %%
#SELECCIÓN DE LA MUESTRA

jb = jb[(jb["country"]=="United States of America") | (jb["country"]=="United States")] #ESTADOS UNIDOS

# %%
#¿NOS QUEDAMOS CON LOS NO MISSING VALUES DE CIUDAD - LAT LONG - Y QUE SEAN DE US?
# POR MI PARTE SI
# INCLUSO PODEMOS NO QUEDARNOS POR NO MISSING DE CIUDAD Y ESTADO

# %%
jb.shape
# Out:
# (21404, 22)

# %%
#VISUALIZACIÓN
jb.head()
# Out:
#     Unnamed: 0           created_at      tweet_id  \
# 4       262183  2020-10-26 19:42:43  1.320813e+18
# 5       110471  2020-10-20 17:41:50  1.318608e+18
# 6       111799  2020-10-20 19:02:07  1.318629e+18
# 10      124834  2020-10-21 11:28:03  1.318877e+18
# 16      117010  2020-10-21 00:29:49  1.318711e+18
#
#                                                 tweet  likes  retweet_count  \
# 4   @GOP @realDonaldTrump Second #Trump turn would...    0.0            0.0
# 5   The Russian president said the U.S. was making...    0.0            0.0
# 6   Hey @SenJohnBarrasso why not VOTE on the Presi...    0.0            0.0
# 10  How's your pride as an #American doing in the ...    0.0            0.0
# 16  #trump kkkult are the perfect sheep https://t....    0.0            0.0
#
#                  source       user_id      user_name user_screen_name  ...  \
# 4       Twitter Web App  9.380305e+08  Gladys Alicea        g_alicea1  ...
# ...

# %%
jb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21404 entries, 4 to 97091
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            21404 non-null  int64
#  1   created_at            21404 non-null  object
#  2   tweet_id              21404 non-null  float64
#  3   tweet                 21404 non-null  object
#  4   likes                 21404 non-null  float64
#  5   retweet_count         21404 non-null  float64
#  6   source                21399 non-null  object
#  7   user_id               21404 non-null  float64
#  8   user_name             21404 non-null  object
#  9   user_screen_name      21404 non-null  object
#  10  user_description      20211 non-null  object
#  11  user_join_date        21404 non-null  object
#  12  user_followers_count  21404 non-null  float64
#  13  user_location         21404 non-null  object
# ...

# %%
jb.describe()
# Out:
#           Unnamed: 0      tweet_id         likes  retweet_count       user_id  \
# count   21404.000000  2.140400e+04  21404.000000   21404.000000  2.140400e+04
# mean   394408.070314  1.321666e+18     13.099000       2.779247  3.383104e+17
# std    274410.568243  2.651881e+15    387.550951      67.980763  5.006183e+17
# min        20.000000  1.316530e+18      0.000000       0.000000  2.654000e+03
# 25%    165649.000000  1.319452e+18      0.000000       0.000000  8.412405e+07
# 50%    340346.000000  1.322020e+18      0.000000       0.000000  8.217429e+08
# 75%    619307.250000  1.324031e+18      1.000000       0.000000  8.301353e+17
# max    970897.000000  1.325589e+18  35449.000000    6629.000000  1.325399e+18
#
#        user_followers_count           lat          long
# count          2.140400e+04  21404.000000  21404.000000
# mean           1.107125e+04     37.598360    -93.509626
# std            1.048953e+05      4.872736     16.837301
# ...

# %%
#NUMERO DE MISSING VALUES
jb.isnull().sum()
# Out:
# Unnamed: 0                  0
# created_at                  0
# tweet_id                    0
# tweet                       0
# likes                       0
# retweet_count               0
# source                      5
# user_id                     0
# user_name                   0
# user_screen_name            0
# user_description         1193
# user_join_date              0
# user_followers_count        0
# user_location               0
# lat                         0
# long                        0
# city                    11107
# country                     0
# continent                   0
# state                    3363
# state_code               3363
# collected_at                0
# dtype: int64

# %%
#VALORES UNICOS DE COLUMNAS
for i in ["user_location", "city", "country", "continent", "state", "state_code"]:
    print(i, jb[i].unique(), "\n")
# Out:
# user_location ['United States' 'Indianapolis Indiana' 'Arlington, VA' ...
#  'Northwest Arkansas' 'Washington | Berlin' 'Honolulu, Hawaii']
#
# city [nan 'Indianapolis' 'Arlington' 'Chicago' 'New York' 'San Francisco'
#  'Los Angeles' 'Cleveland' 'Tulsa' 'San Diego' 'Nashville' 'Portland'
#  'Garden City' 'El Cajon' 'Atlanta' 'Philadelphia' 'Boston' 'Seattle'
#  'Washington' 'Stamford' 'Daytona Beach' 'Austin' 'Allentown' 'Monterey'
#  'Dallas' 'Houston' 'Red Bay' 'St. Louis' 'San Jose' 'Salt Lake City'
#  'Louisville' 'Rancho Cucamonga' 'Oakland' 'Denver' 'Jacksonville'
#  'Palm Coast' 'Greensboro' 'Tampa' 'Minneapolis' 'Lynchburg' 'Miami'
#  'Charlotte' 'Fayetteville' 'Kansas City' 'Phoenix' 'Baltimore' 'Columbus'
#  'San Rafael' 'Santa Monica' 'Las Vegas' 'Santa Clarita' 'San Antonio'
#  'New Orleans' 'Tuscaloosa' 'Wilmington' 'Biloxi' 'Sioux City' 'Annapolis'
#  'Berkeley' 'Lancaster' 'Oceanside' 'Long Beach' 'Nashua' 'Rochester'
# ...
